# %% [markdown]
# ## zeyad attia

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("retail.csv")

# %% [markdown]
# ## Read dataset

# %%
# the first 5 rows
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     1/1/2020  Northeast  New York  New York
# 1  Foot Locker      1185732     1/2/2020  Northeast  New York  New York
# 2  Foot Locker      1185732     1/3/2020  Northeast  New York  New York
# 3  Foot Locker      1185732     1/4/2020  Northeast  New York  New York
# 4  Foot Locker      1185732     1/5/2020  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear        $50.00       1,200      60,000
# 1    Men's Athletic Footwear        $50.00       1,000      50,000
# 2    Women's Street Footwear        $40.00       1,000      40,000
# 3  Women's Athletic Footwear        $45.00         850      38,250
# 4              Men's Apparel        $60.00         900      54,000
#
#   Operating Profit Sales Method
# 0         $30,000      In-store
# 1         $15,000      In-store
# ...

# %%
# the last five rows
df.tail()
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 9643  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9644  Foot Locker      1185732    1/24/2021  Northeast  New Hampshire
# 9645  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9646  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
# 9647  Foot Locker      1185732    2/22/2021  Northeast  New Hampshire
#
#             City                  Product Price per Unit Units Sold  \
# 9643  Manchester            Men's Apparel        $50.00          64
# 9644  Manchester          Women's Apparel        $41.00         105
# 9645  Manchester    Men's Street Footwear        $41.00         184
# 9646  Manchester  Men's Athletic Footwear        $42.00          70
# 9647  Manchester  Women's Street Footwear        $29.00          83
#
#      Total Sales Operating Profit Sales Method
# 9643         320             $90        Outlet
# ...

# %%
# the info of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   object
#  3   Region            9641 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9646 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Sales Method      9648 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 904.6+ KB

# %%
#checking for not number in data set
df.isna().sum()
# Out:
# Retailer            0
# Retailer ID         0
# Invoice Date        0
# Region              7
# State               0
# City                0
# Product             0
# Price per Unit      2
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Sales Method        0
# dtype: int64

# %% [markdown]
# ### checking for null values

# %%
# showing nan vaules in region column 
df[df['Region'].isna()]
# Out:
#           Retailer  Retailer ID Invoice Date Region       State  \
# 76   Sports Direct      1197831    7/27/2020    NaN       Texas
# 81   Sports Direct      1197831     8/1/2020    NaN       Texas
# 163      West Gear      1128299   12/30/2020    NaN  California
# 168      West Gear      1128299     1/4/2021    NaN  California
# 293    Foot Locker      1185732     6/9/2021    NaN    Illinois
# 297    Foot Locker      1185732    6/13/2021    NaN    Illinois
# 304    Foot Locker      1185732    6/20/2021    NaN    Illinois
#
#               City                    Product Price per Unit Units Sold  \
# 76         Houston    Women's Street Footwear        $35.00         675
# 81         Houston    Men's Athletic Footwear        $40.00         875
# 163  San Francisco            Women's Apparel        $80.00         700
# 168  San Francisco              Men's Apparel        $65.00         550
# 293        Chicago  Women's Athletic Footwear        $40.00         100
# ...

# %%
# cheking for texas region 
df[df['State']=="Texas"]
# Out:
#            Retailer  Retailer ID Invoice Date Region  State     City  \
# 72    Sports Direct      1197831    7/23/2020  South  Texas  Houston
# 73    Sports Direct      1197831    7/24/2020  South  Texas  Houston
# 74    Sports Direct      1197831    7/25/2020  South  Texas  Houston
# 75    Sports Direct      1197831    7/26/2020  South  Texas  Houston
# 76    Sports Direct      1197831    7/27/2020    NaN  Texas  Houston
# ...             ...          ...          ...    ...    ...      ...
# 8131  Sports Direct      1197831   10/21/2021  South  Texas   Dallas
# 8132    Foot Locker      1185732   10/22/2021  South  Texas   Dallas
# 8133    Foot Locker      1185732   10/23/2021  South  Texas   Dallas
# 8134    Foot Locker      1185732   10/24/2021  South  Texas   Dallas
# 8135    Foot Locker      1185732   10/25/2021  South  Texas   Dallas
#
#                         Product Price per Unit Units Sold Total Sales  \
# ...

# %%
df[df['State']=="California"]
# Out:
#          Retailer  Retailer ID Invoice Date Region       State           City  \
# 144     West Gear      1128299    11/5/2020   West  California  San Francisco
# 145     West Gear      1128299    11/6/2020   West  California  San Francisco
# 146     West Gear      1128299    11/7/2020   West  California  San Francisco
# 147     West Gear      1128299    11/8/2020   West  California  San Francisco
# 148     West Gear      1128299    11/9/2020   West  California  San Francisco
# ...           ...          ...          ...    ...         ...            ...
# 8059       Kohl's      1189833    5/30/2021   West  California    Los Angeles
# 8060  Foot Locker      1185732    5/31/2021   West  California    Los Angeles
# 8061  Foot Locker      1185732     6/1/2021   West  California    Los Angeles
# 8062  Foot Locker      1185732     6/2/2021   West  California    Los Angeles
# 8063  Foot Locker      1185732     6/3/2021   West  California    Los Angeles
#
# ...

# %%
df[df['State']=="Illinois"]
# Out:
#            Retailer  Retailer ID Invoice Date   Region     State     City  \
# 288     Foot Locker      1185732     6/4/2021  Midwest  Illinois  Chicago
# 289     Foot Locker      1185732     6/5/2021  Midwest  Illinois  Chicago
# 290     Foot Locker      1185732     6/6/2021  Midwest  Illinois  Chicago
# 291     Foot Locker      1185732     6/7/2021  Midwest  Illinois  Chicago
# 292     Foot Locker      1185732     6/8/2021  Midwest  Illinois  Chicago
# ...             ...          ...          ...      ...       ...      ...
# 4243    Foot Locker      1185732    8/10/2021  Midwest  Illinois  Chicago
# 4244  Sports Direct      1197831    8/11/2021  Midwest  Illinois  Chicago
# 4245  Sports Direct      1197831    8/12/2021  Midwest  Illinois  Chicago
# 4246  Sports Direct      1197831    8/13/2021  Midwest  Illinois  Chicago
# 4247  Sports Direct      1197831    8/14/2021  Midwest  Illinois  Chicago
#
#                         Product Price per Unit Units Sold Total Sales  \
# ...

# %%
# show nan vaules in price per unit column
df[df['Price per Unit'].isna()]
# Out:
#          Retailer  Retailer ID Invoice Date     Region     State      City  \
# 16    Foot Locker      1185732    1/29/2020  Northeast  New York  New York
# 78  Sports Direct      1197831    7/29/2020      South     Texas   Houston
#
#           Product Price per Unit Units Sold Total Sales Operating Profit  \
# 16  Men's Apparel            NaN        850      51,000         $15,300
# 78  Men's Apparel            NaN        500      20,000          $6,000
#
#    Sales Method
# 16       Outlet
# 78       Outlet

# %% [markdown]
# ### remove unrelated char from data

# %%
# remover $ from price per unit 
df['Price per Unit'] = df['Price per Unit'].str.replace('$','')
df.head()
# Out:
# C:\Users\zeyad\AppData\Local\Temp/ipykernel_13360/631592365.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price per Unit'] = df['Price per Unit'].str.replace('$','')
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     1/1/2020  Northeast  New York  New York
# 1  Foot Locker      1185732     1/2/2020  Northeast  New York  New York
# 2  Foot Locker      1185732     1/3/2020  Northeast  New York  New York
# 3  Foot Locker      1185732     1/4/2020  Northeast  New York  New York
# 4  Foot Locker      1185732     1/5/2020  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear         50.00       1,200      60,000
# 1    Men's Athletic Footwear         50.00       1,000      50,000
# ...

# %%
# remover $ from Units Sold 
df['Units Sold'] = df['Units Sold'].str.replace(',','')
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     1/1/2020  Northeast  New York  New York
# 1  Foot Locker      1185732     1/2/2020  Northeast  New York  New York
# 2  Foot Locker      1185732     1/3/2020  Northeast  New York  New York
# 3  Foot Locker      1185732     1/4/2020  Northeast  New York  New York
# 4  Foot Locker      1185732     1/5/2020  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear         50.00        1200      60,000
# 1    Men's Athletic Footwear         50.00        1000      50,000
# 2    Women's Street Footwear         40.00        1000      40,000
# 3  Women's Athletic Footwear         45.00         850      38,250
# 4              Men's Apparel         60.00         900      54,000
#
#   Operating Profit Sales Method
# 0         $30,000      In-store
# 1         $15,000      In-store
# ...

# %%
# remover $ from Total Sales 
df['Total Sales'] = df['Total Sales'].str.replace(',','')
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     1/1/2020  Northeast  New York  New York
# 1  Foot Locker      1185732     1/2/2020  Northeast  New York  New York
# 2  Foot Locker      1185732     1/3/2020  Northeast  New York  New York
# 3  Foot Locker      1185732     1/4/2020  Northeast  New York  New York
# 4  Foot Locker      1185732     1/5/2020  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear         50.00        1200       60000
# 1    Men's Athletic Footwear         50.00        1000       50000
# 2    Women's Street Footwear         40.00        1000       40000
# 3  Women's Athletic Footwear         45.00         850       38250
# 4              Men's Apparel         60.00         900       54000
#
#   Operating Profit Sales Method
# 0         $30,000      In-store
# 1         $15,000      In-store
# ...

# %%
# remover $ from Operating Profit 
df['Operating Profit'] = df['Operating Profit'].str.replace(',','')
df.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     1/1/2020  Northeast  New York  New York
# 1  Foot Locker      1185732     1/2/2020  Northeast  New York  New York
# 2  Foot Locker      1185732     1/3/2020  Northeast  New York  New York
# 3  Foot Locker      1185732     1/4/2020  Northeast  New York  New York
# 4  Foot Locker      1185732     1/5/2020  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear         50.00        1200       60000
# 1    Men's Athletic Footwear         50.00        1000       50000
# 2    Women's Street Footwear         40.00        1000       40000
# 3  Women's Athletic Footwear         45.00         850       38250
# 4              Men's Apparel         60.00         900       54000
#
#   Operating Profit Sales Method
# 0          $30000      In-store
# 1          $15000      In-store
# ...

# %%
df['Operating Profit'] = df['Operating Profit'].str.replace('$','')
df.head()
# Out:
# C:\Users\zeyad\AppData\Local\Temp/ipykernel_13360/4159545187.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Operating Profit'] = df['Operating Profit'].str.replace('$','')
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     1/1/2020  Northeast  New York  New York
# 1  Foot Locker      1185732     1/2/2020  Northeast  New York  New York
# 2  Foot Locker      1185732     1/3/2020  Northeast  New York  New York
# 3  Foot Locker      1185732     1/4/2020  Northeast  New York  New York
# 4  Foot Locker      1185732     1/5/2020  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear         50.00        1200       60000
# ...

# %% [markdown]
# ## change types of data

# %%
#changing the type of price per unit
df['Price per Unit'] = df['Price per Unit'].astype(float)
df.dtypes
# Out:
# Retailer             object
# Retailer ID           int64
# Invoice Date         object
# Region               object
# State                object
# City                 object
# Product              object
# Price per Unit      float64
# Units Sold           object
# Total Sales          object
# Operating Profit     object
# Sales Method         object
# dtype: object

# %%
#changing the type of Units Sold
df['Units Sold'] = df['Units Sold'].astype(int)
df.dtypes
# Out:
# Retailer             object
# Retailer ID           int64
# Invoice Date         object
# Region               object
# State                object
# City                 object
# Product              object
# Price per Unit      float64
# Units Sold            int32
# Total Sales          object
# Operating Profit     object
# Sales Method         object
# dtype: object

# %%
#changing the type of Total Sales
df['Total Sales'] = df['Total Sales'].astype(int)
df.dtypes
# Out:
# Retailer             object
# Retailer ID           int64
# Invoice Date         object
# Region               object
# State                object
# City                 object
# Product              object
# Price per Unit      float64
# Units Sold            int32
# Total Sales           int32
# Operating Profit     object
# Sales Method         object
# dtype: object

# %%
#changing the type of Operating Profit
df['Operating Profit'] = df['Operating Profit'].astype(int)
df.dtypes
# Out:
# Retailer             object
# Retailer ID           int64
# Invoice Date         object
# Region               object
# State                object
# City                 object
# Product              object
# Price per Unit      float64
# Units Sold            int32
# Total Sales           int32
# Operating Profit      int32
# Sales Method         object
# dtype: object

# %%
# change Invoice date from object to date
df["Invoice Date"] = pd.to_datetime(df["Invoice Date"])
df.dtypes
# Out:
# Retailer                    object
# Retailer ID                  int64
# Invoice Date        datetime64[ns]
# Region                      object
# State                       object
# City                        object
# Product                     object
# Price per Unit             float64
# Units Sold                   int32
# Total Sales                  int32
# Operating Profit             int32
# Sales Method                object
# dtype: object

# %% [markdown]
# ## remove retailer id column

# %%
df.drop('Retailer ID', inplace=True, axis=1)

# %%
df.head()
# Out:
#       Retailer Invoice Date     Region     State      City  \
# 0  Foot Locker   2020-01-01  Northeast  New York  New York
# 1  Foot Locker   2020-01-02  Northeast  New York  New York
# 2  Foot Locker   2020-01-03  Northeast  New York  New York
# 3  Foot Locker   2020-01-04  Northeast  New York  New York
# 4  Foot Locker   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200        60000
# 1    Men's Athletic Footwear            50.0        1000        50000
# 2    Women's Street Footwear            40.0        1000        40000
# 3  Women's Athletic Footwear            45.0         850        38250
# 4              Men's Apparel            60.0         900        54000
#
#    Operating Profit Sales Method
# 0             30000     In-store
# 1             15000     In-store
# 2             14000     In-store
# 3             13388     In-store
# ...

# %%
# chaning invoice date to date 
df.rename(columns={"Invoice Date": "Date"}, inplace=True)

# %% [markdown]
# ## dealing with nan values

# %%
df[df['Product']=="Men's Apparel"]
# Out:
#          Retailer       Date     Region          State        City  \
# 4     Foot Locker 2020-01-05  Northeast       New York    New York
# 10    Foot Locker 2020-01-23  Northeast       New York    New York
# 16    Foot Locker 2020-01-29  Northeast       New York    New York
# 22    Foot Locker 2020-02-04  Northeast       New York    New York
# 28    Foot Locker 2020-02-10  Northeast       New York    New York
# ...           ...        ...        ...            ...         ...
# 9619       Amazon 2021-09-17  Northeast  New Hampshire  Manchester
# 9625  Foot Locker 2021-10-19  Northeast  New Hampshire  Manchester
# 9631  Foot Locker 2021-11-18  Northeast  New Hampshire  Manchester
# 9637  Foot Locker 2021-12-17  Northeast  New Hampshire  Manchester
# 9643  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
#
#             Product  Price per Unit  Units Sold  Total Sales  \
# 4     Men's Apparel            60.0         900        54000
# ...

# %%
# get the median of product men's apparel 
df[df['Product']=="Men's Apparel"]['Price per Unit'].median()
# Out:
# 50.0

# %%
# replace nan values with median
df['Price per Unit'].fillna(df[df['Product']=="Men's Apparel"]['Price per Unit'].median(),inplace=True)

# %%
# check if it perform or not
df[df['Product']=="Men's Apparel"]
# Out:
#          Retailer       Date     Region          State        City  \
# 4     Foot Locker 2020-01-05  Northeast       New York    New York
# 10    Foot Locker 2020-01-23  Northeast       New York    New York
# 16    Foot Locker 2020-01-29  Northeast       New York    New York
# 22    Foot Locker 2020-02-04  Northeast       New York    New York
# 28    Foot Locker 2020-02-10  Northeast       New York    New York
# ...           ...        ...        ...            ...         ...
# 9619       Amazon 2021-09-17  Northeast  New Hampshire  Manchester
# 9625  Foot Locker 2021-10-19  Northeast  New Hampshire  Manchester
# 9631  Foot Locker 2021-11-18  Northeast  New Hampshire  Manchester
# 9637  Foot Locker 2021-12-17  Northeast  New Hampshire  Manchester
# 9643  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
#
#             Product  Price per Unit  Units Sold  Total Sales  \
# 4     Men's Apparel            60.0         900        54000
# ...

# %%
df.head()
# Out:
#       Retailer       Date     Region     State      City  \
# 0  Foot Locker 2020-01-01  Northeast  New York  New York
# 1  Foot Locker 2020-01-02  Northeast  New York  New York
# 2  Foot Locker 2020-01-03  Northeast  New York  New York
# 3  Foot Locker 2020-01-04  Northeast  New York  New York
# 4  Foot Locker 2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200        60000
# 1    Men's Athletic Footwear            50.0        1000        50000
# 2    Women's Street Footwear            40.0        1000        40000
# 3  Women's Athletic Footwear            45.0         850        38250
# 4              Men's Apparel            60.0         900        54000
#
#    Operating Profit Sales Method
# 0             30000     In-store
# 1             15000     In-store
# 2             14000     In-store
# 3             13388     In-store
# ...

# %%
# replace nan valuse in region column 
# df[df['State']=="Texas"]["Region"].fillna("South",inplace=True)

# %%
# df[df['State']=="California"]["Region"].fillna("West",inplace=True)

# %%
# df[df['State']=="Illinois"]["Region"].fillna("Midwest",inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Retailer            0
# Date                0
# Region              0
# State               0
# City                0
# Product             0
# Price per Unit      0
# Units Sold          0
# Total Sales         0
# Operating Profit    0
# Sales Method        0
# dtype: int64

# %%
# checking if it perform or not 
df[df['Region'].isna()]
# Out:
# Empty DataFrame
# Columns: [Retailer, Date, Region, State, City, Product, Price per Unit, Units Sold, Total Sales, Operating Profit, Sales Method]
# Index: []

# %% [markdown]
#  <b> i tried to replace the null values with the right vaule but it give me an error so i droped them
#     i wish to give me feedback on how to replace them

# %% [markdown]
# ## dealing with out liers

# %%
df.head()
# Out:
#       Retailer       Date     Region     State      City  \
# 0  Foot Locker 2020-01-01  Northeast  New York  New York
# 1  Foot Locker 2020-01-02  Northeast  New York  New York
# 2  Foot Locker 2020-01-03  Northeast  New York  New York
# 3  Foot Locker 2020-01-04  Northeast  New York  New York
# 4  Foot Locker 2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200        60000
# 1    Men's Athletic Footwear            50.0        1000        50000
# 2    Women's Street Footwear            40.0        1000        40000
# 3  Women's Athletic Footwear            45.0         850        38250
# 4              Men's Apparel            60.0         900        54000
#
#    Operating Profit Sales Method
# 0             30000     In-store
# 1             15000     In-store
# 2             14000     In-store
# 3             13388     In-store
# ...

# %%
# checking for out liers
sns.catplot(x="Price per Unit",
           data = df,
           kind="box")

# %%
# removing Price per Unit over 100
df=df[df["Price per Unit"]<100]
df
# Out:
#          Retailer       Date     Region          State        City  \
# 0     Foot Locker 2020-01-01  Northeast       New York    New York
# 1     Foot Locker 2020-01-02  Northeast       New York    New York
# 2     Foot Locker 2020-01-03  Northeast       New York    New York
# 3     Foot Locker 2020-01-04  Northeast       New York    New York
# 4     Foot Locker 2020-01-05  Northeast       New York    New York
# ...           ...        ...        ...            ...         ...
# 9643  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 0         Men's Street Footwear            50.0        1200        60000
# ...

# %%
sns.catplot(x="Price per Unit",
           data = df,
           kind="box")

# %%
# checking for out liers
sns.catplot(x="Units Sold",
           data = df,
           kind="box")

# %%
df_3= df[df["Units Sold"]>1200]
df_3
# Out:
#        Retailer       Date     Region     State      City  \
# 6   Foot Locker 2020-01-07  Northeast  New York  New York
# 12  Foot Locker 2020-01-25  Northeast  New York  New York
# 24  Foot Locker 2020-02-06  Northeast  New York  New York
# 30  Foot Locker 2020-03-04  Northeast  New York  New York
# 36  Foot Locker 2020-03-10  Northeast  New York  New York
# 42  Foot Locker 2020-03-16  Northeast  New York  New York
#
#                   Product  Price per Unit  Units Sold  Total Sales  \
# 6   Men's Street Footwear            50.0        1250        62500
# 12  Men's Street Footwear            50.0        1220        61000
# 24  Men's Street Footwear            60.0        1220        73200
# 30  Men's Street Footwear            60.0        1250        75000
# 36  Men's Street Footwear            60.0        1275        76500
# 42  Men's Street Footwear            60.0        1250        75000
#
#     Operating Profit Sales Method
# 6              31250     In-store
# ...

# %%
# checking for out liers
sns.catplot(x="Units Sold",
           data = df,
           kind="box")

# %%
# checking for out liers
sns.catplot(x="Total Sales",
           data = df,
           kind="box")

# %%
df=df[df["Total Sales"]<80000]
df
# Out:
#          Retailer       Date     Region          State        City  \
# 0     Foot Locker 2020-01-01  Northeast       New York    New York
# 1     Foot Locker 2020-01-02  Northeast       New York    New York
# 2     Foot Locker 2020-01-03  Northeast       New York    New York
# 3     Foot Locker 2020-01-04  Northeast       New York    New York
# 4     Foot Locker 2020-01-05  Northeast       New York    New York
# ...           ...        ...        ...            ...         ...
# 9643  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 0         Men's Street Footwear            50.0        1200        60000
# ...

# %%
sns.catplot(x="Total Sales",
           data = df,
           kind="box")

# %%
sns.catplot(x="Operating Profit",
           data = df,
           kind="box")

# %% [markdown]
# ## use your power and techniques to clean and process data

# %% [markdown]
# - replace non relevant characters
# - handle nan values
# - handle missing values
# - handle outliers
# - handle date and time
# - drop non relevant columns
# - try to extract relational features.

# %%
df.head()
# Out:
#       Retailer       Date     Region     State      City  \
# 0  Foot Locker 2020-01-01  Northeast  New York  New York
# 1  Foot Locker 2020-01-02  Northeast  New York  New York
# 2  Foot Locker 2020-01-03  Northeast  New York  New York
# 3  Foot Locker 2020-01-04  Northeast  New York  New York
# 4  Foot Locker 2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200        60000
# 1    Men's Athletic Footwear            50.0        1000        50000
# 2    Women's Street Footwear            40.0        1000        40000
# 3  Women's Athletic Footwear            45.0         850        38250
# 4              Men's Apparel            60.0         900        54000
#
#    Operating Profit Sales Method
# 0             30000     In-store
# 1             15000     In-store
# 2             14000     In-store
# 3             13388     In-store
# ...

# %% [markdown]
# ### I need form you to give me a dataframe with only values like New York from State column

# %%
df_2= df[df["State"] == "New York"]

# %%
df_2
# Out:
#            Retailer       Date     Region     State      City  \
# 0       Foot Locker 2020-01-01  Northeast  New York  New York
# 1       Foot Locker 2020-01-02  Northeast  New York  New York
# 2       Foot Locker 2020-01-03  Northeast  New York  New York
# 3       Foot Locker 2020-01-04  Northeast  New York  New York
# 4       Foot Locker 2020-01-05  Northeast  New York  New York
# ...             ...        ...        ...       ...       ...
# 7843        Walmart 2020-07-18  Northeast  New York  New York
# 7844  Sports Direct 2020-07-19  Northeast  New York  New York
# 7845  Sports Direct 2020-07-20  Northeast  New York  New York
# 7846  Sports Direct 2020-07-21  Northeast  New York  New York
# 7847  Sports Direct 2020-07-22  Northeast  New York  New York
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 0         Men's Street Footwear            50.0        1200        60000
# ...

# %% [markdown]
# ## is there any relation between year and Total Sales ?

# %%
df.groupby(df.Date.dt.year)['Total Sales'].sum()
# Out:
# Date
# 2020    17968475
# 2021    70694572
# Name: Total Sales, dtype: int32

# %%
df.groupby (df.Date.dt.year).agg(overall_sales= ('Total Sales' , 'sum'))
# Out:
#       overall_sales
# Date
# 2020       17968475
# 2021       70694572

# %%
sns.relplot(x="Total Sales",
           y="Date",
           data=df,
           kind="scatter")

# %% [markdown]
# ## is there any relation between month and Total Sales ?

# %%
df.groupby (df.Date.dt.month_name()).agg(overall_sales= ('Total Sales' , 'sum'))
# Out:
#            overall_sales
# Date
# April            7234017
# August           9020135
# December         8528218
# February         6110037
# January          7112187
# July             8977642
# June             7006061
# March            5680937
# May              8050788
# November         6785744
# October          6391117
# September        7766164

# %% [markdown]
# <b>i did my best to add the valus of year and month to df to make a scatter plot but i can't after i research for about 1 hour on this part only

# %% [markdown]
# ## is there any core relation between your features ?

# %%
df.corr()
# Out:
#                   Price per Unit  Units Sold  Total Sales  Operating Profit
# Price per Unit          1.000000    0.257931     0.421534          0.381360
# Units Sold              0.257931    1.000000     0.916288          0.894261
# Total Sales             0.421534    0.916288     1.000000          0.956220
# Operating Profit        0.381360    0.894261     0.956220          1.000000

# %%
sns.relplot(x="Units Sold",
           y="Operating Profit",
           data=df,
           kind="scatter")

# %%
sns.relplot(x="Units Sold",
           y="Total Sales",
           data=df,
           kind="scatter")

# %%
sns.relplot(x="Operating Profit",
           y="Total Sales",
           data=df,
           kind="scatter")

# %% [markdown]
# ## What is the highest product count in Retailer column ????

# %%
df["Retailer"].value_counts()
# Out:
# Foot Locker      2630
# West Gear        2362
# Sports Direct    2030
# Kohl's           1030
# Amazon            949
# Walmart           620
# Name: Retailer, dtype: int64

# %%
g=sns.catplot(x="Retailer",
            data=df,
            kind="count",
            ci= None)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## What is the highest product with Total Sales ?

# %%
df["Product"].value_counts()
# Out:
# Men's Athletic Footwear      1608
# Men's Street Footwear        1606
# Women's Street Footwear      1606
# Women's Athletic Footwear    1605
# Men's Apparel                1604
# Women's Apparel              1591
# Men's aparel                    1
# Name: Product, dtype: int64

# %%
g = sns.catplot(x="Product",
            y="Total Sales",
            data=df,
            kind="bar",
            ci= None)
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## If there any problem with Price per Unit column ?, if not please visualize the distribution of it.

# %% [markdown]
# <b> i resolved almost any problem in the data

# %%
sns.histplot(x="Price per Unit",
            data=df
            )
# Out:
# <AxesSubplot:xlabel='Price per Unit', ylabel='Count'>

# %% [markdown]
# ### Give me the Total Sales for Northeast only in one chart!

# %%
df_north=df[df["Region"]=="Northeast"]
df_north
# Out:
#          Retailer       Date     Region          State        City  \
# 0     Foot Locker 2020-01-01  Northeast       New York    New York
# 1     Foot Locker 2020-01-02  Northeast       New York    New York
# 2     Foot Locker 2020-01-03  Northeast       New York    New York
# 3     Foot Locker 2020-01-04  Northeast       New York    New York
# 4     Foot Locker 2020-01-05  Northeast       New York    New York
# ...           ...        ...        ...            ...         ...
# 9643  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
# 9644  Foot Locker 2021-01-24  Northeast  New Hampshire  Manchester
# 9645  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
# 9646  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
# 9647  Foot Locker 2021-02-22  Northeast  New Hampshire  Manchester
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 0         Men's Street Footwear            50.0        1200        60000
# ...

# %%
sns.catplot(x="Region",
            y="Total Sales",
            data=df_north,
            kind="bar",
            ci= None,
            hue= "State")

# %% [markdown]
# ### What is the highest Sales Method with total sales?

# %%
df.head()
# Out:
#       Retailer       Date     Region     State      City  \
# 0  Foot Locker 2020-01-01  Northeast  New York  New York
# 1  Foot Locker 2020-01-02  Northeast  New York  New York
# 2  Foot Locker 2020-01-03  Northeast  New York  New York
# 3  Foot Locker 2020-01-04  Northeast  New York  New York
# 4  Foot Locker 2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200        60000
# 1    Men's Athletic Footwear            50.0        1000        50000
# 2    Women's Street Footwear            40.0        1000        40000
# 3  Women's Athletic Footwear            45.0         850        38250
# 4              Men's Apparel            60.0         900        54000
#
#    Operating Profit Sales Method
# 0             30000     In-store
# 1             15000     In-store
# 2             14000     In-store
# 3             13388     In-store
# ...

# %%
df["Sales Method"].value_counts()
# Out:
# Online      4881
# Outlet      3010
# In-store    1730
# Name: Sales Method, dtype: int64

# %%
sns.catplot(x="Sales Method",
            data=df,
            kind="count",
            ci= None)

# %% [markdown]
# ### What is the highest Sales Method in South region ?

# %%
df_north["Sales Method"].value_counts()
# Out:
# Online      936
# Outlet      757
# In-store    683
# Name: Sales Method, dtype: int64

# %%
sns.catplot(x="Sales Method",
            data=df_north,
            kind="count",
            ci= None)
